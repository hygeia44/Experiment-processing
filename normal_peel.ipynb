# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import *
# %matplotlib inline

# x vs y with trendline
df = pd.read_csv("C:/Users/hygei/Documents/Code/normalPeel.csv", na_values=" NaN")
fig = plt.figure()
ax= plt.axes()
rg = "Asc"
y1= df.loc[df["region"] == rg, "Delamination Strength mN/mm"]
x1 = df.loc[df["region"] == rg, "distensibility"]
ax.scatter(x1, y1,marker='v')
# ax.get_xaxis().set_ticks([])
# plt.ylabel('Dissection Energy (mJ/$cm^2$)', fontsize=16)
plt.ylabel('Delamination Strength (mN/mm)', fontsize=16)
# plt.xlabel('Anterior               Left                Posterior               Right', fontsize=12)
# plt.xlabel('RCS                LCS                 NCS               Posterior', fontsize=12)
plt.xlabel('In-Vivo Stiffness (kPa)', fontsize=16)
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)
plt.title ('Ascending Aorta', fontsize=16)
# ax.scatter(1, median(y1), marker='_', s= 160, color='k')
plt.xlim([0,2500])
# adding trend line
z = np.polyfit(x1, y1, 1)
p = np.poly1d(z)
ax.plot(x1,p(x1),"k-")
plt.show()

# %%
#box and whisker plot with matplotlib
import numpy as np
import matplotlib.pyplot as plt
# from matplotlib.pyplot import *
import pandas as pd

df = pd.read_csv("C:/Users/hygei/Documents/Code/normalPeel.csv", na_values=" NaN")
df1 = pd.read_csv("C:/Users/hygei/Documents/Code/ataaPeel.csv", na_values=" NaN")
dirc = 'long'
para = 'Dissection Engergy mJ/cm2'
# para ='Delamination Strength mN/mm'
# df= df1[~np.isnan(df1)]
d1=df.loc[(df["direction"] == dirc )& (df["subregion"] == 'Asc Ant') , para ]
d2=df.loc[(df["direction"] == dirc )& (df["subregion"] == 'Asc Med') , para ]
d3=df.loc[(df["direction"] == dirc )& (df["subregion"] == 'Asc Post') , para]
d4=df.loc[(df["direction"] == dirc )& (df["subregion"] == 'Asc Lat') , para]
d5=df.loc[(df["direction"] == dirc )& (df["region"] == 'Asc') , para]
d6=df.loc[(df["direction"] == dirc )& (df["region"] == 'stj') , para]
#
d7=df1.loc[(df1["direction"] == dirc )& (df1["subregion"] == 'Asc Ant') , para ]
d8=df1.loc[(df1["direction"] == dirc )& (df1["subregion"] == 'Asc Med') , para ]
d9=df1.loc[(df1["direction"] == dirc )& (df1["subregion"] == 'Asc Post') , para]
d10=df1.loc[(df1["direction"] == dirc )& (df1["subregion"] == 'Asc Lat') , para]
d11 =df1.loc[(df1["direction"] == dirc )& (df1["region"] == 'Asc') , para]
# d1 = df.groupby(by=["Subregion"])
# d1 = df ['ac'].dropna().values
# d1.shape = (-1, 1)
data = [d1, d2, d3, d4]
# data = [d7, d8, d9, d10]
# data = [d5, d6]
fig = plt.figure(figsize=(6, 4))
# plt.boxplot(data, showfliers=False)
plt.boxplot(data)

# plt.boxplot(data)
#############add raw data points
# for i in [1,2,3,4]:
# # for i in [1,2]:
#     y = data[i-1].dropna()
# #     Add some random "jitter" to the x-axis
#     x = np.random.normal(i, 0.04, size=len(y))
#     plt.plot(x, y, 'b.', alpha=0.2)  
#############end of add raw data points
plt.xlabel('Anterior    Medial     Posterior    Lateral\n Ascending Aorta', fontsize=14, multialignment='center')
# plt.xlabel('ATAA             Normal', fontsize=16, multialignment='center')
plt.ylabel('Dissection Energy (mJ/$cm^2$)', fontsize=14)
# plt.xlabel('Ascending Aorta   Sinotubular Junction',  fontsize=14)
# plt.ylabel('Delamination Strength (mN/mm)', fontsize=14)
plt.yticks(fontsize=16)
# fig.suptitle('Circumferential', fontsize=14) 
fig.suptitle('Longitudinal', fontsize=14) 
# fig.suptitle('Normal - Ascending Aorta - Longitudinal', fontsize=16)
# fig.suptitle('Normal - Ascending Aorta - Longitudinal', fontsize=16)
# fig.suptitle('ATAA - Ascending Aorta - Longitudinal', fontsize=16)
# plt.ylim([0,120])
plt.ylim([0,22.5])
# remove the tick
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.show()

# %%
# from scipy.stats import iqr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statistics as sta

df = pd.read_csv("C:/Users/hygei/Documents/Code/normalPeel.csv", na_values=" NaN")
df1 = pd.read_csv("C:/Users/hygei/Documents/Code/ataaPeel.csv", na_values=" NaN")
dirc = 'long'
# para = 'Dissection Engergy mJ/cm2'
para ='Delamination Strength mN/mm'
# df= df1[~np.isnan(df1)]
# d1=df.loc[(df["direction"] == dirc )& (df["subregion"] == 'STJ Lat') , para ]
d1=df.loc[df["region"] == 'Asc' , para ]
# d1=df.loc[(df["direction"] == dirc )& (df["region"] == 'stj') , para ]
q1, q3 = np.percentile(d1, [25 ,75])
sta.median(d1), q1, q3
# stat, p = mannwhitneyu(d1, d2, alternative=None)
# p
# Out:
# (39.65517166, 31.611294530000002, 53.47608747)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import *

# subregion stress plot with median bar
fig = plt.figure()
ax= plt.axes()
y1 = [0.764071118, 0.870051914, 0.634881828, 1.145632251, 1.303110826]
# plt.setp(ax.get_xticklabels(), rotation='vertical', fontsize=14)
# plt.xticks(fontsize=14, rotation=90)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# plt.xlabel('Asc Ant  Asc Med  Asc Post   Asc Lat    STJ Lat', fontsize=16)
plt.xlabel('Anterior  Medial   Posterior  Lateral Lateral\n Ascending Aorta                          STJ', fontsize=16, multialignment='center')
plt.ylabel('Anisotropy Index', fontsize=16)
plt.ylim([0.5,1.4])
# remove the tick
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax.plot(y1, marker='s', color='k')

# %%
# move to the next section (Material property plot)  del
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

### Set your path to the folder containing the .csv files
PATH = 'C:/Users/hygei/Documents/Code/data/' 

### Fetch all files in path
fileNames = os.listdir(PATH)

### Filter file name list for files ending with .csv
fileNames = [file for file in fileNames if '.csv' in file]

### Loop over all files
for file in fileNames:

    ### Read .csv file and append to list
    df = pd.read_csv(PATH + file, index_col =None, header=0, sep='\s*,\s*', encoding='ascii', engine='python')
    strn = df['elongation'] - min(df['elongation'])
    strs = df['force/width'] - min(df['force/width'])
#     pr = np.polyfit(strn, strs, 2)
#     ns = np.poly1d(pr)
    
#     plt.plot(strn,ns(strn))
    yhat = savgol_filter(df['force/width'], 15, 2)*1000 # window size 51, polynomial order 3
#     plt.plot(df['elongation'],df['force/width'])
    plt.plot(df['elongation'],yhat)
    plt.xlabel('Elongation (mm)', fontsize=16)
    plt.ylabel('Force/Width (mN/mm)', fontsize=16)
    plt.ylim([0,60])
    plt.xlim([0,38])
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.title('Circumferential', fontsize=16)
    ### Create line for every file
    #plt.plot(df['Epsilon_XX'], df['Stress_XX'])

    #draw avrage one
    
    
## Generate the plot
# plt.show()

# %%
# plot mean and std from raw data
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("C:/Users/hygei/Documents/Code/thickness.csv", na_values=" NaN")
df1=df.agg([np.mean, np.std])
fig = plt.figure(figsize=(7, 4))
ax= plt.axes()

x = np.array([1, 2, 3, 4, 6, 7, 8, 9, 11, 12, 13])
y= df1.loc['mean',:]
e= df1.loc['std',:]


plt.errorbar(x, y, e, linestyle='None', fmt='-o', capsize=3)
plt.ylabel('Thickness (mm)', fontsize=12)
# plt.xlabel('Anterior               Left                Posterior               Right', fontsize=12)
# plt.xlabel('RCS                LCS                 NCS               Posterior', fontsize=12)
plt.xlabel('  Ant Med Post Lat           Ant Med Post Lat            RCS LCS  NCS \n      Ascending                            STJ                           Sinus', fontsize=12, multialignment='left')
# plt.title ('Aneurysmal Aorta Sinus Longitudinal')
# plt.ylim([1,3])
# plt.ylim([0,3000])
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.show()
plt.clf()

# %%
#plot with seaborn boxplot with point data
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
# from matplotlib.patches import PathPatch

# def adjust_box_widths(g, fac):
#     """
#     Adjust the withs of a seaborn-generated boxplot.
#     """

#     # iterating through Axes instances
#     for ax in g.axes:

#         # iterating through axes artists:
#         for c in ax.get_children():

#             # searching for PathPatches
#             if isinstance(c, PathPatch):
#                 # getting current width of box:
#                 p = c.get_path()
#                 verts = p.vertices
#                 verts_sub = verts[:-1]
#                 xmin = np.min(verts_sub[:, 0])
#                 xmax = np.max(verts_sub[:, 0])
#                 xmid = 0.5*(xmin+xmax)
#                 xhalf = 0.5*(xmax - xmin)

#                 # setting new width of box
#                 xmin_new = xmid-fac*xhalf
#                 xmax_new = xmid+fac*xhalf
#                 verts_sub[verts_sub[:, 0] == xmin, 0] = xmin_new
#                 verts_sub[verts_sub[:, 0] == xmax, 0] = xmax_new

#                 # setting new width of median line
#                 for l in ax.lines:
#                     if np.all(l.get_xdata() == [xmin, xmax]):
#                         l.set_xdata([xmin_new, xmax_new])

df = pd.read_csv("C:/Users/hygei/Documents/Code/normal2.csv", na_values=" NaN")
# df = pd.read_csv("C:/Users/hygei/Documents/Code/failStress.csv", na_values=" NaN")
# dfplt = df[['asc ant long','asc med long', 'asc post long','asc lat long', 'stj ant long', 'stj lat long']]
# dfplt.boxplot(grid=False, rot=45, fontsize=15)
# df.boxplot(grid=False, rot=45, fontsize=12, figsize=(8,4))

# make boxplot with Seaborn
# bplot=sns.boxplot(y='Failure Stress (Kpa)', x='Circumferential                     Longitudinal', 
#                  data=df, 
#                  width=0.5,
#                  color='white')
# plt.setp(bplot.artists, edgecolor = 'k', facecolor='w')
# plt.setp(bplot.lines, color='k')
fig = plt.figure(figsize=(8, 7))
sns.set_style("white")
sns.set(font_scale=2)
bplot=sns.boxplot(y='Longitudinal Stress (Kpa) averaged', x='Subregions', 
                                    data=df, 
                 width=0.5,
                 palette="colorblind",
                 showfliers = False)

# adjust_box_widths(fig, 3)
 
# add stripplot to boxplot with Seaborn
# bplot=sns.stripplot(y='Circumferential Stress (Kpa) averaged', x='Subregions', 
#                    data=df, 
#                    jitter=True, 
#                    marker='o', 
#                    alpha=0.5,
#                    color='black')

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("C:/Users/hygei/Documents/Code/Marfan.csv", na_values=" NaN")
# d1 = df["sinus image"].value_counts()

index = np.arange(47)
bar_width = 0.35

fig, ax = plt.subplots(figsize=(20, 4))
summer = ax.bar(index,df['asc image'], bar_width,
                label="Image")

winter = ax.bar(index+bar_width, df["asc simulation"],
                 bar_width, label="Simulation")

ax.set_xlabel('Category')
ax.set_ylabel('Diameter Measurement (mm)')
ax.set_title('Ascending')
ax.set_xticks(index + bar_width / 2)
# ax.set_xticklabels(["ASB", "Violence", "Theft", "Public Order", "Drugs"])
ax.legend()
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.xlim([-1,47])
plt.show()
